# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d11_text_meta_2002_06_12.txt'
meta_data1 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data1
# Out:
#           ID  Fwy Dir  District  County     City State_PM  Abs_PM   Latitude  \
# 0    1100270   94   W        11      73  66000.0     1.95   0.534  32.713274
# 1    1100307    5   N        11      73  66000.0  R18.876  18.767  32.746575
# 2    1100310    5   N        11      73  66000.0  R20.663  20.554  32.767779
# 3    1100313    5   N        11      73  66000.0  R22.092  21.983  32.788206
# 4    1100326    5   N        11      73  66000.0  R36.043  35.934  32.976740
# ..       ...  ...  ..       ...     ...      ...      ...     ...        ...
# 641  1111572  805   N        11      73  66000.0      3.2   3.051  32.588107
# 642  1111573  805   N        11      73  66000.0    14.83  14.681  32.734572
# 643  1111574  805   N        11      73  66000.0    13.98  13.831  32.725845
# 644  1111577    5   N        11      73  66000.0   R32.98  32.871  32.933367
# 645  1111578   15   S        11      73  66000.0  M14.982  15.229  32.903115
#
#       Longitude  Length Type  Lanes                  Name  User_ID_1  \
# 0   -117.138818     NaN   FR      2               25TH ST          1
# 1   -117.190957     NaN   FR      1        MOORE/OLD TOWN        188
# 2   -117.205941     NaN   FR      2          SEA WORLD DR        223
# 3   -117.206890     NaN   FR      1         CLAIREMONT DR        151
# 4   -117.251751     NaN   FR      2       VIA DE LA VALLE        130
# ..          ...     ...  ...    ...                   ...        ...
# 641 -117.036209   5.000   ML      4           NB 805 @ 15         69
# 642 -117.113181     NaN   FF      2  NB 15 TO NB 805 CONN         69
# 643 -117.103188     NaN   FF      4  WB 94 TO NB 805 CONN         70
# 644 -117.241134   2.583   HV      1  HOVNB 5 @ CARMEL VAL         85
# 645 -117.116630   4.779   HV      2  HOV @ CARROLL CANYON         95
#
#      User_ID_2  User_ID_3  User_ID_4
# 0          NaN        NaN        NaN
# 1          NaN        NaN        NaN
# 2          NaN        NaN        NaN
# 3          NaN        NaN        NaN
# 4          NaN        NaN        NaN
# ..         ...        ...        ...
# 641        NaN        NaN        NaN
# 642        NaN        NaN        NaN
# 643        NaN        NaN        NaN
# 644        NaN        NaN        NaN
# 645        NaN        NaN        NaN
#
# [646 rows x 18 columns]

# %%
meta_data1.ID.unique()
print('ID number: ',len(meta_data1.ID.unique()))
# Out:
# ID number:  646

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d11_text_meta_2011_02_04.txt'
meta_data2 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data2.ID.unique()
print('ID number 2: ',len(meta_data2.ID.unique()))
meta_data2
# Out:
# ID number 2:  1221
#            ID  Fwy Dir  District  County     City State_PM  Abs_PM   Latitude  \
# 0     1100310    5   N        11      73  66000.0  R20.663  20.554  32.767779
# 1     1100313    5   N        11      73  66000.0  R22.092  21.983  32.788206
# 2     1100323    5   N        11      73  66000.0  R33.979  33.870  32.947766
# 3     1100326    5   N        11      73  66000.0  R36.043  35.934  32.976740
# 4     1100330    5   N        11      73  66000.0  R37.246  37.137  32.993716
# ...       ...  ...  ..       ...     ...      ...      ...     ...        ...
# 1216  1120724    5   N        11      73  66000.0  R31.904  31.795  32.918784
# 1217  1120732    5   N        11      73  72506.0   R37.31  37.201  32.994635
# 1218  1120740    5   S        11      73  66000.0   R37.35  37.241  32.995208
# 1219  1120749    5   S        11      73  66000.0  R31.659  31.517  32.916250
# 1220  1120754    5   S        11      73  66000.0  R31.659  31.517  32.916250
#
#        Longitude  Length Type  Lanes                 Name  User_ID_1  \
# 0    -117.205941     NaN   FR      2         SEA WORLD DR        223
# 1    -117.206890     NaN   FR      1        CLAIREMONT DR        151
# 2    -117.243147     NaN   FR      2       DEL MAR HTS RD        129
# 3    -117.251751     NaN   FR      2      VIA DE LA VALLE        130
# 4    -117.256045     NaN   FR      2       LOMAS SANTA FE        341
# ...          ...     ...  ...    ...                  ...        ...
# 1216 -117.235428     NaN   OR      3    NB5 Carmel Mtn Rd        329
# 1217 -117.256182     NaN   OR      2   NB5 Lomas Santa WB        132
# 1218 -117.256294     NaN   OR      2  SB5 Lomas San Fe EB        107
# 1219 -117.232541     NaN   FR      2   Carmel Mt. To SB 5        333
# 1220 -117.232541   0.619   ML      4   Carmel Mt. To SB 5        333
#
#       User_ID_2  User_ID_3  User_ID_4
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 1216        NaN        NaN        NaN
# 1217        NaN        NaN        NaN
# 1218        NaN        NaN        NaN
# 1219        NaN        NaN        NaN
# 1220        NaN        NaN        NaN
#
# [1221 rows x 18 columns]

# %%
meta_data2.ID.unique()
# Out:
# array([1000110, 1000210, 1000310, 1000410, 1000510, 1000610, 1000710,
#        1000810, 1000910, 1001010, 1001110, 1001210, 1001310, 1001410,
#        1001510, 1001610, 1001710, 1001810, 1001910, 1002010, 1002110,
#        1002210, 1002310, 1002410, 1002510, 1002610, 1002710, 1002810,
#        1002910, 1003010, 1003110, 1003210, 1003310, 1003410, 1003510,
#        1003610, 1003710, 1003810, 1003910, 1004010, 1004110, 1004210,
#        1004310, 1004410, 1004510, 1004610, 1004710, 1004810, 1004910,
#        1005010, 1005110, 1005210, 1005310, 1005410, 1005510, 1005610,
#        1005710, 1005810, 1005910, 1006010, 1006110, 1006210, 1006310,
#        1006410, 1006510, 1006610, 1006710, 1006810, 1006910, 1007010,
#        1007110, 1007210, 1007310, 1007410, 1007510, 1007610, 1007710,
#        1007810, 1007910, 1008010, 1008110, 1008210, 1008310, 1008410,
#        1008510, 1008610, 1008710, 1008810, 1008910, 1009010, 1009110,
#        1009210, 1009310, 1009410, 1009510, 1009610, 1009710, 1009810,
#        1009910, 1010210, 1010310, 1010410, 1010510, 1010610, 1010710,
#        1010810, 1010910, 1011110, 1011210, 1011410, 1011510, 1011610,
#        1011710, 1012210, 1012310, 1012410, 1012510, 1012810, 1012910,
#        1013010, 1013110, 1013210, 1013310, 1013410, 1013510, 1013610,
#        1013710, 1013810, 1013910, 1014010, 1014110, 1014210, 1014310,
#        1014410, 1014510, 1014610, 1014710, 1014810, 1014910, 1015010,
#        1015110, 1015210, 1015310, 1015810, 1015910, 1016010, 1016210,
#        1016310, 1016410, 1016510, 1016610, 1016710, 1016810, 1016910,
#        1017010, 1017110, 1017210, 1017310, 1017410, 1017510, 1017610,
#        1017710, 1017810, 1017910, 1018010, 1018110, 1018210, 1018310,
#        1018410, 1018510, 1018610, 1018710, 1018810, 1018910, 1019110,
#        1019210, 1019310, 1019410, 1019510, 1019610, 1019710, 1019810,
#        1019910, 1020010, 1020110, 1020210, 1020310], dtype=int64)

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d11_text_meta_2017_03_17.txt'
meta_data3 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data3.ID.unique()
print('ID number 3: ',len(meta_data3.ID.unique()))
meta_data3
# Out:
# ID number 3:  1521
#            ID  Fwy Dir  District  County     City State_PM  Abs_PM   Latitude  \
# 0     1100313    5   N        11      73  66000.0  R22.324  22.215  32.791540
# 1     1100323    5   N        11      73  66000.0  R34.142  34.033  32.950106
# 2     1100326    5   N        11      73  66000.0  R36.232  36.123  32.979357
# 3     1100330    5   N        11      73  66000.0   R37.37  37.261  32.995494
# 4     1100333    5   N        11      73  22678.0   R38.54  38.431  33.010364
# ...       ...  ...  ..       ...     ...      ...      ...     ...        ...
# 1516  1126672   15   S        11      73  66000.0   M5.613   5.205  32.763403
# 1517  1126696   15   N        11      73      NaN   M28.27  28.527  33.086775
# 1518  1126699   15   S        11      73      NaN  M28.269  28.516  33.086691
# 1519  1126702   15   N        11      73      NaN  R29.499  29.756  33.100548
# 1520  1126722   15   S        11      73      NaN  R48.281  48.528  33.357354
#
#        Longitude  Length Type  Lanes                  Name  User_ID_1  \
# 0    -117.207160     NaN   FR      1         CLAIREMONT DR        151
# 1    -117.243571     NaN   FR      2        DEL MAR HTS RD        129
# 2    -117.252719     NaN   FR      2       VIA DE LA VALLE        130
# 3    -117.256350     NaN   FR      2        LOMAS SANTA FE        341
# 4    -117.264530     NaN   FR      1        MANCHESTER AVE        133
# ...          ...     ...  ...    ...                   ...        ...
# 1516 -117.109432   0.149   ML      5      15 SB @ Adam Ave      21014
# 1517 -117.076401   1.097   HV      2  15 NB HVS/O Felicita      22713
# 1518 -117.076716   0.390   HV      2  15SB HV S/O Felicita      22712
# 1519 -117.090049   1.225   HV      2  15 NB HVN/O Felicita      22803
# 1520 -117.159131   3.315   ML      4      15 SB N/O Rte 76       4114
#
#       User_ID_2  User_ID_3  User_ID_4
# 0           NaN        NaN        NaN
# 1           NaN        NaN        NaN
# 2           NaN        NaN        NaN
# 3           NaN        NaN        NaN
# 4           NaN        NaN        NaN
# ...         ...        ...        ...
# 1516        NaN        NaN        NaN
# 1517        NaN        NaN        NaN
# 1518        NaN        NaN        NaN
# 1519        NaN        NaN        NaN
# 1520        NaN        NaN        NaN
#
# [1521 rows x 18 columns]

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d11_text_meta_2022_03_16.txt'
meta_data4 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data4.ID.unique()
print('ID number 4: ',len(meta_data4.ID.unique()))
meta_data4
# Out:
# ID number 4:  1440
#            ID  Fwy Dir  District  County     City  State_PM  Abs_PM  \
# 0     1100313    5   N        11      73  66000.0    22.324  22.215
# 1     1100323    5   N        11      73  66000.0    34.142  34.033
# 2     1100326    5   N        11      73  66000.0    36.230  36.121
# 3     1100330    5   N        11      73  72506.0    37.386  37.277
# 4     1100340    5   N        11      73  11194.0    47.165  47.056
# ...       ...  ...  ..       ...     ...      ...       ...     ...
# 1435  1127213   15   S        11      73  66000.0    14.991  15.238
# 1436  1127218  805   N        11      73  66000.0    21.332  21.183
# 1437  1127224  805   N        11      73  66000.0    17.300  17.151
# 1438  1127227   94   W        11      73  66000.0     1.570   0.154
# 1439  1127252  805   N        11      73  66000.0    12.350  12.201
#
#        Latitude   Longitude  Length Type  Lanes                          Name  \
# 0     32.791540 -117.207160     NaN   FR      1         Clairemont Dr to 5 NB
# 1     32.950106 -117.243571     NaN   FR      2    Del Mar Heights Rd to 5 NB
# 2     32.979329 -117.252709     NaN   FR      2    Via de la Valle EB to 5 NB
# 3     32.995723 -117.256395     NaN   FR      2  Lomas Santa Fe Dr EB to 5 NB
# 4     33.123940 -117.322960     NaN   FR      2    Palomar Airport Rd to 5 NB
# ...         ...         ...     ...  ...    ...                           ...
# 1435  32.903245 -117.116630   0.513   ML      6    Carroll Canyon Rd to 15 SB
# 1436  32.817540 -117.159809   0.248   ML      4       Balboa Ave WB to 805 NB
# 1437  32.767405 -117.128984   0.237   ML      4                  805 NB S/O 8
# 1438  32.713385 -117.145037     NaN   FR      2     5 NB connector from 94 WB
# 1439  32.704271 -117.094872   0.883   ML      5  Imperial Ave to 805 NB (BOS)
#
#       User_ID_1  User_ID_2  User_ID_3  User_ID_4
# 0             1        NaN        NaN        NaN
# 1             1        NaN        NaN        NaN
# 2             1        NaN        NaN        NaN
# 3             1        NaN        NaN        NaN
# 4             1        NaN        NaN        NaN
# ...         ...        ...        ...        ...
# 1435          1        NaN        NaN        NaN
# 1436          1        NaN        NaN        NaN
# 1437          1        NaN        NaN        NaN
# 1438          1        NaN        NaN        NaN
# 1439          1        NaN        NaN        NaN
#
# [1440 rows x 18 columns]

# %%
import numpy as np

# # 示例数据，实际数据可能会有不同
# arr1 = np.array(range(400000, 401610))
# arr2 = np.array(range(400500, 402000))
# arr3 = np.array(range(400900, 402500))
# arr4 = np.array(range(400000, 402000))

# 计算四个数组的交集
def find_common_elements(arr1, arr2, arr3, arr4):
