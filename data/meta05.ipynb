# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d05_text_meta_2012_03_07.txt'
meta_data1 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data1
# Out:
#             ID  Fwy Dir  District  County     City  State_PM   Abs_PM  \
# 0    500010092    1   S         5      53  48872.0    77.632  328.101
# 1    500010093    1   N         5      53  48872.0    77.633  328.168
# 2    500010101    1   N         5      53  48872.0    78.023  328.558
# 3    500010102    1   S         5      53  48872.0    78.024  328.493
# 4    500010121    1   S         5      53  48872.0    78.546  329.015
# ..         ...  ...  ..       ...     ...      ...       ...      ...
# 148  501017043  101   N         5      79  68154.0    29.652  203.196
# 149  501017051  101   N         5      79  68154.0    30.024  203.568
# 150  501017052  101   S         5      79  68154.0    30.025  203.542
# 151  501017061  101   N         5      79      NaN    30.953  204.497
# 152  501017062  101   S         5      79      NaN    30.954  204.471
#
#       Latitude   Longitude  Length Type  Lanes  \
# 0    36.593416 -121.876677   2.696   ML      2
# 1    36.593216 -121.876628   2.695   ML      2
# 2    36.594593 -121.869761   0.457   ML      2
# 3    36.594697 -121.869852   0.457   ML      2
# 4    36.600103 -121.863630   0.497   ML      2
# ..         ...         ...     ...  ...    ...
# 148  35.291784 -120.655535   0.437   ML      2
# 149  35.291755 -120.648986   0.651   ML      2
# 150  35.291923 -120.648894   0.652   ML      2
# 151  35.295370 -120.633652   2.964   ML      2
# 152  35.295494 -120.633606   2.964   ML      2
#
#                                  Name  User_ID_1  User_ID_2  User_ID_3  \
# 0      SLOAT AVE HWY 1 SB VDS MLSB SB        NaN        NaN        NaN
# 1      SLOAT AVE HWY 1 SB VDS MLNB NB        NaN        NaN        NaN
# 2    SOUTH OF HWY 68 EAST AT HWY 1 NB        NaN        NaN        NaN
# 3    SOUTH OF HWY 68 EAST AT HWY 1 NB        NaN        NaN        NaN
# 4    CASA VERDE WAY HWY 1 SB VDS MLSB        NaN        NaN        NaN
# ..                                ...        ...        ...        ...
# 148  GRAND AVE IN SLO AT 101 SB VDS M        NaN        NaN        NaN
# 149    MONTEREY ST 101 NB VDS MLNB NB        NaN        NaN        NaN
# 150    MONTEREY ST 101 NB VDS MLSB SB        NaN        NaN        NaN
# 151  FOX HOLLOW RD 101 NB VDS MLNB NB        NaN        NaN        NaN
# 152  FOX HOLLOW RD 101 NB VDS MLSB SB        NaN        NaN        NaN
#
#      User_ID_4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 152        NaN
#
# [153 rows x 18 columns]

# %%
meta_data1.ID.unique()
print('ID number: ',len(meta_data1.ID.unique()))
# Out:
# ID number:  153

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d05_text_meta_2012_03_07.txt'
meta_data2 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data2.ID.unique()
print('ID number 2: ',len(meta_data2.ID.unique()))
meta_data2
# Out:
# ID number 2:  153
#             ID  Fwy Dir  District  County     City  State_PM   Abs_PM  \
# 0    500010092    1   S         5      53  48872.0    77.632  328.101
# 1    500010093    1   N         5      53  48872.0    77.633  328.168
# 2    500010101    1   N         5      53  48872.0    78.023  328.558
# 3    500010102    1   S         5      53  48872.0    78.024  328.493
# 4    500010121    1   S         5      53  48872.0    78.546  329.015
# ..         ...  ...  ..       ...     ...      ...       ...      ...
# 148  501017043  101   N         5      79  68154.0    29.652  203.196
# 149  501017051  101   N         5      79  68154.0    30.024  203.568
# 150  501017052  101   S         5      79  68154.0    30.025  203.542
# 151  501017061  101   N         5      79      NaN    30.953  204.497
# 152  501017062  101   S         5      79      NaN    30.954  204.471
#
#       Latitude   Longitude  Length Type  Lanes  \
# 0    36.593416 -121.876677   2.696   ML      2
# 1    36.593216 -121.876628   2.695   ML      2
# 2    36.594593 -121.869761   0.457   ML      2
# 3    36.594697 -121.869852   0.457   ML      2
# 4    36.600103 -121.863630   0.497   ML      2
# ..         ...         ...     ...  ...    ...
# 148  35.291784 -120.655535   0.437   ML      2
# 149  35.291755 -120.648986   0.651   ML      2
# 150  35.291923 -120.648894   0.652   ML      2
# 151  35.295370 -120.633652   2.964   ML      2
# 152  35.295494 -120.633606   2.964   ML      2
#
#                                  Name  User_ID_1  User_ID_2  User_ID_3  \
# 0      SLOAT AVE HWY 1 SB VDS MLSB SB        NaN        NaN        NaN
# 1      SLOAT AVE HWY 1 SB VDS MLNB NB        NaN        NaN        NaN
# 2    SOUTH OF HWY 68 EAST AT HWY 1 NB        NaN        NaN        NaN
# 3    SOUTH OF HWY 68 EAST AT HWY 1 NB        NaN        NaN        NaN
# 4    CASA VERDE WAY HWY 1 SB VDS MLSB        NaN        NaN        NaN
# ..                                ...        ...        ...        ...
# 148  GRAND AVE IN SLO AT 101 SB VDS M        NaN        NaN        NaN
# 149    MONTEREY ST 101 NB VDS MLNB NB        NaN        NaN        NaN
# 150    MONTEREY ST 101 NB VDS MLSB SB        NaN        NaN        NaN
# 151  FOX HOLLOW RD 101 NB VDS MLNB NB        NaN        NaN        NaN
# 152  FOX HOLLOW RD 101 NB VDS MLSB SB        NaN        NaN        NaN
#
#      User_ID_4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 148        NaN
# 149        NaN
# 150        NaN
# 151        NaN
# 152        NaN
#
# [153 rows x 18 columns]

# %%
meta_data2.ID.unique()
# Out:
# array([500010092, 500010093, 500010101, 500010102, 500010121, 500010122,
#        500010132, 500010133, 500010142, 500010143, 500010152, 500010153,
#        500011021, 500011022, 500011032, 500011033, 500011042, 500011043,
#        500011052, 500011053, 500011062, 500011063, 500011072, 500011073,
#        500011092, 500011102, 500011112, 500011113, 500011121, 500011123,
#        500011141, 500011143, 500013111, 500013112, 500013131, 500013132,
#        500013151, 500013152, 500014021, 500014022, 500014031, 500014032,
#        500014041, 500014042, 500014052, 500014053, 500014062, 500014063,
#        500014071, 500014072, 500014081, 500014082, 500014091, 500014092,
#        500014101, 500014102, 500014111, 500014112, 500014121, 500014122,
#        500014132, 500014133, 500014142, 500017011, 500017012, 501010022,
#        501010023, 501010031, 501010032, 501010052, 501010053, 501010061,
#        501010062, 501010082, 501010083, 501010102, 501010103, 501010112,
#        501010113, 501010122, 501010124, 501010131, 501010132, 501010142,
#        501010152, 501010153, 501011021, 501011032, 501011041, 501011081,
#        501011082, 501011091, 501011092, 501011111, 501011112, 501011121,
#        501011122, 501011131, 501011132, 501011141, 501011142, 501011151,
#        501011152, 501012021, 501012022, 501012042, 501012043, 501012051,
#        501012052, 501012061, 501012062, 501012071, 501012072, 501012081,
#        501012082, 501012091, 501012092, 501012101, 501012102, 501012111,
#        501012112, 501016031, 501016032, 501016042, 501016043, 501016071,
#        501016072, 501016081, 501016082, 501016091, 501016092, 501016101,
#        501016102, 501016122, 501016123, 501016131, 501016132, 501016142,
#        501016143, 501016152, 501016153, 501017011, 501017012, 501017022,
#        501017023, 501017032, 501017033, 501017042, 501017043, 501017051,
#        501017052, 501017061, 501017062], dtype=int64)

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d05_text_meta_2016_05_10.txt'
meta_data3 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data3.ID.unique()
print('ID number 3: ',len(meta_data3.ID.unique()))
meta_data3
# Out:
# ID number 3:  202
#             ID  Fwy Dir  District  County  City  State_PM   Abs_PM   Latitude  \
# 0    500010011    1   N         5      53   NaN    72.330  322.865  36.535850
# 1    500010012    1   S         5      53   NaN    72.331  322.800  36.535860
# 2    500010021    1   N         5      53   NaN    72.757  323.292  36.541075
# 3    500010022    1   S         5      53   NaN    72.758  323.227  36.541106
# 4    500010031    1   N         5      53   NaN    73.726  324.261  36.554647
# ..         ...  ...  ..       ...     ...   ...       ...      ...        ...
# 197  501560032  156   E         5      69   NaN     1.710    8.079  36.847924
# 198  501560061  156   W         5      69   NaN     7.564   13.933  36.846036
# 199  501560062  156   E         5      69   NaN     7.565   13.934  36.846047
# 200  501560081  156   E         5      69   NaN    12.023   18.392  36.904651
# 201  501560082  156   W         5      69   NaN    12.024   18.393  36.904663
#
#       Longitude  Length Type  Lanes                              Name  \
# 0   -121.912881   2.713   ML      1  CARMEL RIV BRIDGE HWY 1 NB VDS M
# 1   -121.912870   2.714   ML      1  CARMEL RIV BRIDGE HWY 1 NB VDS M
# 2   -121.908778   0.697   ML      1  CARMEL VALLEY RD HWY 1 NB VDS ML
# 3   -121.908820   0.698   ML      1  CARMEL VALLEY RD HWY 1 NB VDS ML
# 4   -121.910926   0.831   ML      2    OCEAN AVE HWY 1 NB VDS MLNB NB
# ..          ...     ...  ...    ...                               ...
# 197 -121.554642   4.179   ML      2  WEST OF MONTEREY ST ON HWY 156 W
# 198 -121.454392   4.730   ML      1  BUSINESS RTE 156 ON HWY 156 WB V
# 199 -121.454385   4.729   ML      1  BUSINESS RTE 156 ON HWY 156 WB V
# 200 -121.424310   4.729   ML      1  NORTH OF RTE 25 ON HWY 156 EB VD
# 201 -121.424301   4.730   ML      1  NORTH OF RTE 25 ON HWY 156 EB VD
#
#      User_ID_1  User_ID_2  User_ID_3  User_ID_4
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...
# 197        NaN        NaN        NaN        NaN
# 198        NaN        NaN        NaN        NaN
# 199        NaN        NaN        NaN        NaN
# 200        NaN        NaN        NaN        NaN
# 201        NaN        NaN        NaN        NaN
#
# [202 rows x 18 columns]

# %%
import pandas as pd

# Replace 'your_file_path.txt' with the actual path of your file
file_path = './meta/d05_text_meta_2024_01_19.txt'
meta_data4 = pd.read_csv(file_path, delimiter='\t', header=0)
meta_data4.ID.unique()
print('ID number 4: ',len(meta_data4.ID.unique()))
meta_data4
# Out:
# ID number 4:  573
#             ID  Fwy Dir  District  County  City State_PM   Abs_PM   Latitude  \
# 0    500010011    1   N         5      53   NaN    72.33  322.865  36.535850
# 1    500010012    1   S         5      53   NaN   72.331  322.800  36.535860
# 2    500010021    1   N         5      53   NaN   72.757  323.292  36.541075
# 3    500010022    1   S         5      53   NaN   72.758  323.227  36.541106
# 4    500010031    1   N         5      53   NaN   73.726  324.261  36.554647
# ..         ...  ...  ..       ...     ...   ...      ...      ...        ...
# 568  506800131   68   E         5      53   NaN   17.257   17.461  36.625285
# 569  506800132   68   E         5      53   NaN   17.258   17.462  36.625294
# 570  506800141   68   E         5      53   NaN   18.224   18.428  36.634694
# 571  506800142   68   E         5      53   NaN   18.225   18.429  36.634707
# 572  506800143   68   E         5      53   NaN   18.226   18.430  36.634719
#
#       Longitude  Length Type  Lanes                              Name  \
# 0   -121.912881   2.713   ML      1  CARMEL RIV BRIDGE HWY 1 NB VDS M
# 1   -121.912870   2.714   ML      1  CARMEL RIV BRIDGE HWY 1 NB VDS M
# 2   -121.908778   0.697   ML      2  CARMEL VALLEY RD HWY 1 NB VDS ML
# 3   -121.908820   0.698   ML      1  CARMEL VALLEY RD HWY 1 NB VDS ML
# 4   -121.910926   0.831   ML      2    OCEAN AVE HWY 1 NB VDS MLNB NB
# ..          ...     ...  ...    ...                               ...
# 568 -121.680718   0.814   ML      2  RESERVATION & RIVER RD HWY 68 EB
# 569 -121.680703   0.483   ML      2  RESERVATION & RIVER RD HWY 68 EB
# 570 -121.668155   0.483   ML      2  SPRECKELS BLVD HWY 68 EB VDS MLE
# 571 -121.668147   2.500   ML      2  SPRECKELS BLVD HWY 68 EB VDS MLW
# 572 -121.668140     NaN   FR      1  SPRECKELS BLVD HWY 68 EB VDS OFW
#
#      User_ID_1  User_ID_2  User_ID_3  User_ID_4
# 0            1        NaN        NaN        NaN
# 1            1        NaN        NaN        NaN
# 2            1        NaN        NaN        NaN
# 3            1        NaN        NaN        NaN
# 4            1        NaN        NaN        NaN
# ..         ...        ...        ...        ...
# 568          1        NaN        NaN        NaN
# 569          1        NaN        NaN        NaN
# 570          1        NaN        NaN        NaN
# 571          1        NaN        NaN        NaN
# 572          1        NaN        NaN        NaN
#
# [573 rows x 18 columns]

# %%
import numpy as np

# # 示例数据，实际数据可能会有不同
# arr1 = np.array(range(400000, 401610))
# arr2 = np.array(range(400500, 402000))
# arr3 = np.array(range(400900, 402500))
# arr4 = np.array(range(400000, 402000))

# 计算四个数组的交集
def find_common_elements(arr1, arr2, arr3, arr4):
    common12 = np.intersect1d(arr1, arr2)
    common123 = np.intersect1d(common12, arr3)
    common1234 = np.intersect1d(common123, arr4)
    return common1234

# 调用函数（在最终版本中取消注释）
common_elements = find_common_elements(meta_data4.ID.unique(), meta_data3.ID.unique(), meta_data2.ID.unique(), meta_data1.ID.unique())
print('common number 4: ',len(common_elements))
np.save('pems05_comm.npy',common_elements)
common_elements
# Out:
# common number 4:  103
# array([500010092, 500010093, 500010101, 500010102, 500010121, 500010122,
#        500010142, 500010143, 500011021, 500011022, 500011032, 500011033,
#        500011052, 500011053, 500011062, 500011063, 500011072, 500011073,
#        500011092, 500011102, 500011121, 500011123, 500011141, 500011143,
#        500014091, 500014092, 500014101, 500014102, 500014111, 500014112,
#        500014121, 500014122, 500014132, 500014133, 500017011, 500017012,
#        501010022, 501010023, 501010031, 501010032, 501010052, 501010053,
#        501010061, 501010062, 501010102, 501010103, 501010112, 501010113,
#        501010131, 501010132, 501010152, 501010153, 501011032, 501011041,
#        501011091, 501011092, 501011121, 501011122, 501011131, 501011132,
#        501011141, 501011142, 501011151, 501012021, 501012022, 501012042,
#        501012043, 501012071, 501012072, 501012081, 501012082, 501012101,
#        501012102, 501012111, 501012112, 501016071, 501016072, 501016081,
#        501016082, 501016091, 501016092, 501016101, 501016102, 501016122,
#        501016123, 501016131, 501016132, 501016142, 501016143, 501016152,
#        501016153, 501017011, 501017012, 501017022, 501017023, 501017032,
#        501017033, 501017042, 501017043, 501017051, 501017052, 501017061,
#        501017062], dtype=int64)
